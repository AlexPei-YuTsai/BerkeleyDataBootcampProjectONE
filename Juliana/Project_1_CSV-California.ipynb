# %% [markdown]
# # State Wage

# %%
# Dependencies and Setup
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

# File to Load (Remember to Change These)
wage_estimates_to_load = Path("output/May 2022 State Occupational Employment and Wage Estimates.csv")


# Read School and Student Data File and store into Pandas DataFrames
wage_estimates = pd.read_csv(wage_estimates_to_load)

wage_estimates.head()
# Out:
#    AREA AREA_TITLE  AREA_TYPE PRIM_STATE  NAICS     NAICS_TITLE  \
# 0     1    Alabama          2         AL      0  Cross-industry
# 1     1    Alabama          2         AL      0  Cross-industry
# 2     1    Alabama          2         AL      0  Cross-industry
# 3     1    Alabama          2         AL      0  Cross-industry
# 4     1    Alabama          2         AL      0  Cross-industry
#
#           I_GROUP  OWN_CODE OCC_CODE                        OCC_TITLE  ...  \
# 0  cross-industry      1235  00-0000                  All Occupations  ...
# 1  cross-industry      1235  11-0000           Management Occupations  ...
# 2  cross-industry      1235  11-1011                 Chief Executives  ...
# 3  cross-industry      1235  11-1021  General and Operations Managers  ...
# 4  cross-industry      1235  11-1031                      Legislators  ...
#
#   H_MEDIAN H_PCT75 H_PCT90 A_PCT10  A_PCT25  A_MEDIAN  A_PCT75  A_PCT90  \
# ...

# %% [markdown]
# ---
#
# ### Step 1:

# %%
# Remove unwanted columms
wage_estimates = wage_estimates.drop(['AREA_TYPE', 'NAICS', 'O_GROUP', 'TOT_EMP', 'JOBS_1000','PCT_TOTAL', 'MEAN_PRSE', 'H_PCT10', 'H_PCT25', 'PRIM_STATE', 'EMP_PRSE', 'I_GROUP', 'LOC_QUOTIENT', 'PCT_RPT', 'OWN_CODE', 'OCC_CODE', 'H_PCT75', 'H_PCT90', 'A_PCT10','A_PCT25', 'A_PCT75', 'A_PCT90'], axis=1)
wage_estimates.head()
# Out:
#    AREA AREA_TITLE     NAICS_TITLE                        OCC_TITLE H_MEAN  \
# 0     1    Alabama  Cross-industry                  All Occupations  24.34
# 1     1    Alabama  Cross-industry           Management Occupations  53.13
# 2     1    Alabama  Cross-industry                 Chief Executives  91.67
# 3     1    Alabama  Cross-industry  General and Operations Managers  58.00
# 4     1    Alabama  Cross-industry                      Legislators      *
#
#     A_MEAN H_MEDIAN A_MEDIAN ANNUAL HOURLY
# 0   50,620    18.50   38,470    NaN    NaN
# 1  110,500    46.12   95,940    NaN    NaN
# 2  190,680    65.83  136,930    NaN    NaN
# 3  120,640    47.17   98,120    NaN    NaN
# 4   30,000        *   20,320   True    NaN

# %% [markdown]
# ### Step 2:

# %%
# Rename the columns
wage_estimates = wage_estimates.rename(columns={
    'AREA_TITLE': 'State',
    'NAICS_TITLE': 'Industry',
    'OCC_TITLE': 'Occupation',
    'H_MEAN': 'Average hourly wage',
    'A_MEAN': 'Average annual wage',
    'H_MEDIAN': 'Median hourly wage',
    'A_MEDIAN': 'Median annual wage'
})

wage_estimates.head()
# Out:
#    AREA    State        Industry                       Occupation  \
# 0     1  Alabama  Cross-industry                  All Occupations
# 1     1  Alabama  Cross-industry           Management Occupations
# 2     1  Alabama  Cross-industry                 Chief Executives
# 3     1  Alabama  Cross-industry  General and Operations Managers
# 4     1  Alabama  Cross-industry                      Legislators
#
#   Average hourly wage Average annual wage Median hourly wage  \
# 0               24.34              50,620              18.50
# 1               53.13             110,500              46.12
# 2               91.67             190,680              65.83
# 3               58.00             120,640              47.17
# 4                   *              30,000                  *
#
#   Median annual wage ANNUAL HOURLY
# 0             38,470    NaN    NaN
# 1             95,940    NaN    NaN
# 2            136,930    NaN    NaN
# 3             98,120    NaN    NaN
# ...

# %% [markdown]
# ### Step 3:

# %%
#show only the rows related to California
california_data = wage_estimates[wage_estimates['State'] == 'California']
california_data.head()
# Out:
#       AREA       State        Industry                       Occupation  \
# 2752     6  California  Cross-industry                  All Occupations
# 2753     6  California  Cross-industry           Management Occupations
# 2754     6  California  Cross-industry                 Chief Executives
# 2755     6  California  Cross-industry  General and Operations Managers
# 2756     6  California  Cross-industry                      Legislators
#
#      Average hourly wage Average annual wage Median hourly wage  \
# 2752               35.20              73,220              23.91
# 2753               74.58             155,120              62.66
# 2754              132.23             275,040             102.10
# 2755               71.28             148,270              56.00
# 2756                   *              74,700                  *
#
#      Median annual wage ANNUAL HOURLY
# 2752             49,740    NaN    NaN
# 2753            130,330    NaN    NaN
# ...

# %% [markdown]
# ### Step 4:

# %%
# show only the rows related to Data Scientists in California
data_scientists_ca = wage_estimates[(wage_estimates['State'] == 'California') & (wage_estimates['Occupation'] == 'Data Scientists')]
data_scientists_ca.head()
# Out:
#       AREA       State        Industry       Occupation Average hourly wage  \
# 2845     6  California  Cross-industry  Data Scientists               70.86
#
#      Average annual wage Median hourly wage Median annual wage ANNUAL HOURLY
# 2845             147,390              60.97            126,810    NaN    NaN

# %% [markdown]
# ### Step 5:

# %%
# State Wage
state_wage = plt.imread("output/StateWageLaw.png")

plt.imshow(state_wage)
plt.axis('off') 
plt.show()
