# %%
# Dependencies and Setup
import pandas as pd
from pathlib import Path

price_house_summary = Path("Resources/rental_price_summary.csv")

price_house_summary_data = pd.read_csv(price_house_summary)
price_house_summary_data
# Out:
#        RegionID  SizeRank  RegionName RegionType StateName State         City  \
# 0         58196      7338        1001        zip        MA    MA       Agawam
# 1         58197      3918        1002        zip        MA    MA      Amherst
# 2         58200     13464        1005        zip        MA    MA        Barre
# 3         58201      7622        1007        zip        MA    MA  Belchertown
# 4         58202     22646        1008        zip        MA    MA    Blandford
# ...         ...       ...         ...        ...       ...   ...          ...
# 26908    100468     20072       99827        zip        AK    AK       Haines
# 26909    100472     17035       99833        zip        AK    AK   Petersburg
# 26910    100473     12624       99835        zip        AK    AK        Sitka
# 26911    100478      8878       99901        zip        AK    AK    Ketchikan
# 26912    100489     23520       99929        zip        AK    AK     Wrangell
#
#                   Metro Home_values Average_2020 Home_values Average_2021  \
# 0       Springfield, MA              $272,653.97              $296,148.92
# 1       Springfield, MA              $411,932.83              $450,103.73
# 2      Worcester, MA-CT              $279,467.69              $313,288.21
# 3       Springfield, MA              $335,314.39              $370,465.74
# 4       Springfield, MA              $263,439.46              $291,691.91
# ...                 ...                      ...                      ...
# 26908               NaN                     $nan              $281,713.06
# 26909               NaN              $281,000.13              $302,322.79
# 26910               NaN              $439,931.61              $478,373.80
# 26911     Ketchikan, AK              $378,065.63              $401,861.07
# 26912               NaN                     $nan                     $nan
#
#       Home_values Average_2022 Home_values Average_2023  \
# 0                  $313,621.32              $317,991.43
# 1                  $484,243.33              $492,780.82
# 2                  $344,679.83              $354,591.55
# 3                  $403,472.14              $410,654.22
# 4                  $316,809.51              $321,534.83
# ...                        ...                      ...
# 26908              $306,235.87              $295,914.76
# 26909              $305,600.20              $302,752.12
# 26910              $495,293.48              $486,119.75
# 26911              $422,173.93              $423,058.19
# 26912              $255,560.03              $248,893.13
#
#       Rental_rates Average_2020 Rental_rates Average_2021  \
# 0                           NaN                       NaN
# 1                          $nan                      $nan
# 2                           NaN                       NaN
# 3                           NaN                       NaN
# 4                           NaN                       NaN
# ...                         ...                       ...
# 26908                       NaN                       NaN
# 26909                       NaN                       NaN
# 26910                       NaN                       NaN
# 26911                       NaN                       NaN
# 26912                       NaN                       NaN
#
#       Rental_rates Average_2022 Rental_rates Average_2023
# 0                           NaN                       NaN
# 1                          $nan                 $2,251.17
# 2                           NaN                       NaN
# 3                           NaN                       NaN
# 4                           NaN                       NaN
# ...                         ...                       ...
# 26908                       NaN                       NaN
# 26909                       NaN                       NaN
# 26910                       NaN                       NaN
# 26911                       NaN                       NaN
# 26912                       NaN                       NaN
#
# [26913 rows x 16 columns]
